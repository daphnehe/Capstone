# %% [markdown]
# # Introduction

# %% [markdown]
# ### The spread of online misinformation poses a serious threat to democracies in the 21st century. It erodes trust in public institutions and increases political polarization, weakening the foundation that democratic systems are built upon.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/daphnehe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/daphnehe/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/daphnehe/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import json
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# # Load the JSON data into a pandas DataFrame
# # Load Human real news
# with open('data/HR.json', 'r') as file:
#     data = json.load(file)

# HR_df = pd.DataFrame.from_dict(data, orient='index')

# %%
# Function to load JSON data into a DataFrame
def load_json_to_df(json_file):
    with open(json_file, 'r') as file:
        data = json.load(file)
    return pd.DataFrame.from_dict(data, orient='index')

# List of JSON files
json_files = ['HR.json', 'HF.json', 'MR.json', 'MF.json']
dfs = []

# Load each JSON file into a DataFrame and store them in a list
for json_file in json_files:
    df = load_json_to_df('data/' + json_file)
    dfs.append(df)

# Naming the DataFrames
HR_df, HF_df, MR_df, MF_df = dfs

# %%
# Human Real News
HR_df
# Out:
#                     id                                               text  \
# 0     gossipcop-951329  11 Summer Camp Movies That'll Make You Nostalg...
# 1     gossipcop-861360  Info Category: Richest Business › Executives N...
# 2     gossipcop-911046  Warning: This story contains major spoilers fr...
# 3     gossipcop-899120  Lil Peep died of an overdose of fentanyl and g...
# 4     gossipcop-919455  Goop is kicking off its weekly podcast in a bi...
# ...                ...                                                ...
# 8163  gossipcop-875489  For free real time breaking news alerts sent s...
# 8164  gossipcop-844263  Gilmore Girls: A Year in the Life made its Net...
# 8165  gossipcop-917467  Why Is It Airing Now?\n\nAccording to the exec...
# 8166  gossipcop-924877  Just when you thought this season of Vanderpum...
# 8167  gossipcop-897086  A cringeworthy video of Katie Couric talking a...
#
#                                                   title  \
# 0     11 Summer Camp Movies That'll Make You Nostalg...
# 1                    Charrisse Jackson Jordan Net Worth
# 2     Raúl Esparza exits Law & Order: SVU after six ...
# 3                      Lil Peep Cause of Death Revealed
# 4     Gwyneth Paltrow, Oprah talk Weinstein, #MeToo’...
# ...                                                 ...
# 8163     The top interior design trends for millennials
# 8164  Gilmore Girls Video: Lauren Graham, Alexis Ble...
# 8165  The O.J. Simpson Interview on Fox: Gripping, G...
# 8166  Kristen Doute and James Kennedy Hooked Up Rumo...
# 8167  Katie Couric Once Said Matt Lauer 'Pinches Me ...
#
#                                             description
# 0     Nothing says summer like watching a movie all ...
# 1         What is Charrisse Jackson Jordan's net worth?
# 2     The actor reveals why he decided to leave the ...
# 3     Pima County Office of the Medical Examiner con...
# 4     Goop is kicking off its weekly podcast in a bi...
# ...                                                 ...
# 8163  From hand-baked clay tiles to LED lights that ...
# 8164  Gilmore Girls: A Year in the Life made its Net...
# 8165  On Sunday Fox aired “O.J. Simpson: The Lost Co...
# 8166  Just when you thought this season of Vanderpum...
# 8167  Video from 2012 shows the former "Today" host ...
#
# [8168 rows x 4 columns]

# %%
# Human Fake News
HF_df
# Out:
#                         id                                               text  \
# 0     gossipcop-1991455469  ✕ Close Meghan Markle and Prince Harry have an...
# 1     gossipcop-7798039260  Kim Kardashian and Kanye West are pulling out ...
# 2     gossipcop-7817725290  Prince Harry and Meghan currently live at Kens...
# 3     gossipcop-5111151830  They can't get enough of the Biebs on this sho...
# 4     gossipcop-9658632569  Ben Affleck is keeping life with his three kid...
# ...                    ...                                                ...
# 4079  gossipcop-7065786957  There was no shortage of celebrity beefs in 20...
# 4080  gossipcop-1188213997  Kim Kardashian and her sisters seem pretty uni...
# 4081  gossipcop-9024002184  When John and I got together, I found my love ...
# 4082  gossipcop-3520745692  Yikes! Less than 3 months after giving birth t...
# 4083  gossipcop-9138527637  Beyoncé Knowles and Jay Z have welcomed twins,...
#
#                                                   title  \
# 0     As it happened: Prince Harry and Meghan Markle...
# 1     Kim & Kanye Install At-Home Panic Room After P...
# 2     £1.4million spent renovating Prince Harry and ...
# 3     Photos from Dancing With the Stars: Special Gu...
# 4     Jennifer Garner ‘Doesn’t Want’ Her Kids Around...
# ...                                                 ...
# 4079                The Biggest Celebrity Feuds of 2017
# 4080  Kim Kardashian Criticizes Scott Disick for Dat...
# 4081  Chrissy Teigen Opens Up for the First Time Abo...
# 4082  Kylie Jenner Suffers Pregnancy Scare 3 Months ...
# 4083                    Beyoncé and Jay Z Welcome Twins
#
#                                             description
# 0            The wedding will take place in spring 2018
# 1     'Keeping the kids safe is the couples number o...
# 2     Prince Harry and Meghan might not be living in...
# 3     Photos from Dancing With the Stars: Special Gu...
# 4     Jennifer Garner ‘doesn’t want’ her three kids ...
# ...                                                 ...
# 4079  There was no shortage of celebrity beefs in 2017.
# 4080               See what Kim said on 'KUWTK' inside!
# 4081  "The mental pain of knowing I let so many peop...
# 4082  Yikes! Less than 3 months after giving birth t...
# 4083  Beyoncé Knowles and Jay Z have welcomed twins,...
#
# [4084 rows x 4 columns]

# %%
# AI Real News
MR_df
# Out:
#                     id                                        description  \
# 0     gossipcop-951329  Nothing says summer like watching a movie all ...
# 1     gossipcop-861360      What is Charrisse Jackson Jordan's net worth?
# 2     gossipcop-911046  The actor reveals why he decided to leave the ...
# 3     gossipcop-899120  Pima County Office of the Medical Examiner con...
# 4     gossipcop-919455  Goop is kicking off its weekly podcast in a bi...
# ...                ...                                                ...
# 4164  gossipcop-849360  Kailyn Lowry revealed she was recently 'hookin...
# 4165  gossipcop-923609  Farrah Abraham, one of the stars of the MTV sh...
# 4166  gossipcop-933361  Kim DePaola can't say enough good things about...
# 4167  gossipcop-902565  See the red carpet looks (and Time's Up black ...
# 4168  gossipcop-927541  Kanye West posted a tribute on Twitter to Khlo...
#
#                                                    text  \
# 0     With summer just around the corner, it's the p...
# 1     Charrisse Jackson Jordan, an American reality ...
# 2     Warning: This story contains major spoilers fr...
# 3     The Pima County Office of the Medical Examiner...
# 4     Goop is kicking off its weekly podcast in a bi...
# ...                                                 ...
# 4164  Kailyn Lowry, star of Teen Mom 2, recently ope...
# 4165  Farrah Abraham, star of MTV's Teen Mom OG, has...
# 4166  The Real Housewives of New Jersey star, Kim De...
# 4167  The 2018 Golden Globes red carpet is one unlik...
# 4168  Kanye West, the renowned rapper and 21-time Gr...
#
#                                                   title
# 0     11 Summer Camp Movies That'll Make You Nostalg...
# 1                    Charrisse Jackson Jordan Net Worth
# 2     Raúl Esparza Exits Law & Order: SVU After Six ...
# 3                    Lil Peep's Cause of Death Revealed
# 4     Gwyneth Paltrow, Oprah Discuss Weinstein and #...
# ...                                                 ...
# 4164  Kailyn Lowry Reveals Regrets About Relationshi...
# 4165  Farrah Abraham Drops $5 Million 'Sex Shaming' ...
# 4166  Real Housewives' Kim DePaola on Botched, Terry...
# 4167  Black but not boring! See the red carpet looks...
# 4168  Kanye West Returns to Twitter, Gets Sentimenta...
#
# [4169 rows x 4 columns]

# %%
# AI Fake News
MF_df
# Out:
#                         id                                               text  \
# 0     gossipcop-1991455469  Excitement and anticipation are in the air as ...
# 1     gossipcop-7798039260  In the wake of Kim Kardashian's traumatic Pari...
# 2     gossipcop-7817725290  uke and Duchess of Sussex, Prince Harry and Me...
# 3     gossipcop-5111151830  In a surprise turn of events, former President...
# 4     gossipcop-9658632569  In an unexpected turn of events, Hollywood act...
# ...                    ...                                                ...
# 4079  gossipcop-7065786957  As we bid farewell to the drama-filled year th...
# 4080  gossipcop-1188213997  Reality television star Kim Kardashian is faci...
# 4081  gossipcop-9024002184  Chrissy Teigen, the popular model and social m...
# 4082  gossipcop-3520745692  Kylie Jenner and Travis Scott's relationship m...
# 4083  gossipcop-9138527637  According to an exclusive report by TMZ, Beyon...
#
#                                                   title  \
# 0     Royal Family prepares to welcome modern bride ...
# 1     Kim and Kanye's At-Home Panic Room Sparks Outr...
# 2     £1.4 Million Renovation for Prince Harry and M...
# 3     Former President Obama and Beyoncé grace the D...
# 4     Jennifer Garner Caught Banning Lindsay Shookus...
# ...                                                 ...
# 4079       The Most Anticipated Celebrity Feuds of 2018
# 4080  Kim Kardashian Accused of Hypocrisy After Crit...
# 4081  Chrissy Teigen Reveals Secret Struggle with Po...
# 4082  Kylie Jenner and Travis Scott's Relationship o...
# 4083  Beyoncé and Jay Z's Twins Named After Famous C...
#
#                                             description
# 0            The wedding will take place in spring 2018
# 1     'Keeping the kids safe is the couples number o...
# 2     Prince Harry and Meghan might not be living in...
# 3     Photos from Dancing With the Stars: Special Gu...
# 4     Jennifer Garner ‘doesn’t want’ her three kids ...
# ...                                                 ...
# 4079  There was no shortage of celebrity beefs in 2017.
# 4080               See what Kim said on 'KUWTK' inside!
# 4081  "The mental pain of knowing I let so many peop...
# 4082  Yikes! Less than 3 months after giving birth t...
# 4083  Beyoncé Knowles and Jay Z have welcomed twins,...
#
# [4084 rows x 4 columns]

# %%
# Data Cleaning
def clean_text(text):
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert text to lowercase
    text = text.lower()
    return text

HR_df['cleaned_text'] = HR_df['text'].apply(clean_text)
HF_df['cleaned_text'] = HF_df['text'].apply(clean_text)
MR_df['cleaned_text'] = MR_df['text'].apply(clean_text)
MF_df['cleaned_text'] = MF_df['text'].apply(clean_text)

# Print the cleaned text for each DataFrame
print("Human Real News:")
print(HR_df['cleaned_text'])
print("\nHuman Fake News:")
print(HF_df['cleaned_text'])
print("\nAI Real News:")
print(MR_df['cleaned_text'])
print("\nAI Fake News:")
print(MF_df['cleaned_text'])
# Out:
# Human Real News:
# 0        summer camp movies thatll make you nostalgic ...
# 1       info category richest business  executives net...
# 2       warning this story contains major spoilers fro...
# 3       lil peep died of an overdose of fentanyl and g...
# 4       goop is kicking off its weekly podcast in a bi...
#                               ...
# 8163    for free real time breaking news alerts sent s...
# 8164    gilmore girls a year in the life made its netf...
# 8165    why is it airing now\n\naccording to the execu...
# 8166    just when you thought this season of vanderpum...
# 8167    a cringeworthy video of katie couric talking a...
# Name: cleaned_text, Length: 8168, dtype: object
#
# Human Fake News:
# 0        close meghan markle and prince harry have ann...
# 1       kim kardashian and kanye west are pulling out ...
# 2       prince harry and meghan currently live at kens...
# 3       they cant get enough of the biebs on this show...
# 4       ben affleck is keeping life with his three kid...
#                               ...
# 4079    there was no shortage of celebrity beefs in \n...
# 4080    kim kardashian and her sisters seem pretty uni...
# 4081    when john and i got together i found my love f...
# 4082    yikes less than  months after giving birth to ...
# 4083    beyonc knowles and jay z have welcomed twins a...
# Name: cleaned_text, Length: 4084, dtype: object
#
# AI Real News:
# 0       with summer just around the corner its the per...
# 1       charrisse jackson jordan an american reality t...
# 2       warning this story contains major spoilers fro...
# 3       the pima county office of the medical examiner...
# 4       goop is kicking off its weekly podcast in a bi...
#                               ...
# 4164    kailyn lowry star of teen mom  recently opened...
# 4165    farrah abraham star of mtvs teen mom og has de...
# 4166    the real housewives of new jersey star kim dep...
# 4167    the  golden globes red carpet is one unlike an...
# 4168    kanye west the renowned rapper and time grammy...
# Name: cleaned_text, Length: 4169, dtype: object
#
# AI Fake News:
# 0       excitement and anticipation are in the air as ...
# 1       in the wake of kim kardashians traumatic paris...
# 2       uke and duchess of sussex prince harry and meg...
# 3       in a surprise turn of events former president ...
# 4       in an unexpected turn of events hollywood actr...
#                               ...
# 4079    as we bid farewell to the dramafilled year tha...
# 4080    reality television star kim kardashian is faci...
# 4081    chrissy teigen the popular model and social me...
# 4082    kylie jenner and travis scotts relationship ma...
# 4083    according to an exclusive report by tmz beyonc...
# Name: cleaned_text, Length: 4084, dtype: object

# %%
# Text Preprocessing
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # Lemmatize the tokens
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    # Join the tokens back into a single string
    processed_text = ' '.join(lemmatized_tokens)
    return processed_text

HR_df['preprocessed_text'] = HR_df['cleaned_text'].apply(preprocess_text)
HF_df['preprocessed_text'] = HF_df['cleaned_text'].apply(preprocess_text)
MR_df['preprocessed_text'] = MR_df['cleaned_text'].apply(preprocess_text)
MF_df['preprocessed_text'] = MF_df['cleaned_text'].apply(preprocess_text)

print("Human Real News:")
print(HR_df['preprocessed_text'])
print("\nHuman Fake News:")
print(HF_df['preprocessed_text'])
print("\nAI Real News:")
print(MR_df['preprocessed_text'])
print("\nAI Fake News:")
print(MF_df['preprocessed_text'])
# Out:
# Human Real News:
# 0       summer camp movie thatll make nostalgic childh...
# 1       info category richest business executive net w...
# 2       warning story contains major spoiler recent ep...
# 3       lil peep died overdose fentanyl generic xanax ...
# 4       goop kicking weekly podcast big way oprah big ...
#                               ...
# 8163    free real time breaking news alert sent straig...
# 8164    gilmore girl year life made netflix debut six ...
# 8165    airing according executive producer terry wron...
# 8166    thought season vanderpump rule couldnt get sca...
# 8167    cringeworthy video katie couric talking matt l...
# Name: preprocessed_text, Length: 8168, dtype: object
#
# Human Fake News:
# 0       close meghan markle prince harry announced eng...
# 1       kim kardashian kanye west pulling stop keep fa...
# 2       prince harry meghan currently live kensington ...
# 3       cant get enough biebs show back first week sea...
# 4       ben affleck keeping life three kid relationshi...
#                               ...
# 4079    shortage celebrity beef whether fight costars ...
# 4080    kim kardashian sister seem pretty unimpressed ...
# 4081    john got together found love cooking one earli...
# 4082    yikes le month giving birth baby stormi kylie ...
# 4083    beyonc knowles jay z welcomed twin according r...
# Name: preprocessed_text, Length: 4084, dtype: object
#
# AI Real News:
# 0       summer around corner perfect time take trip me...
# 1       charrisse jackson jordan american reality tele...
# 2       warning story contains major spoiler recent ep...
# 3       pima county office medical examiner confirmed ...
# 4       goop kicking weekly podcast big way oprah winf...
#                               ...
# 4164    kailyn lowry star teen mom recently opened reg...
# 4165    farrah abraham star mtvs teen mom og decided d...
# 4166    real housewife new jersey star kim depaola rec...
# 4167    golden globe red carpet one unlike time initia...
# 4168    kanye west renowned rapper time grammy winner ...
# Name: preprocessed_text, Length: 4169, dtype: object
#
# AI Fake News:
# 0       excitement anticipation air royal family get r...
# 1       wake kim kardashians traumatic paris robbery r...
# 2       uke duchess sussex prince harry meghan markle ...
# 3       surprise turn event former president barack ob...
# 4       unexpected turn event hollywood actress jennif...
#                               ...
# 4079    bid farewell dramafilled year anticipation wha...
# 4080    reality television star kim kardashian facing ...
# 4081    chrissy teigen popular model social medium per...
# 4082    kylie jenner travis scott relationship may jeo...
# 4083    according exclusive report tmz beyonc jay z na...
# Name: preprocessed_text, Length: 4084, dtype: object

# %%
# Save the preprocessed data to a new JSON file 
# Do this only once!
# HR_df.to_json('HR_prep.json', orient='index')
# HF_df.to_json('HF_prep.json', orient='index')
# MF_df.to_json('MF_prep.json', orient='index')
# MR_df.to_json('MR_prep.json', orient='index')

# %%
# # Load the JSON data into a pandas DataFrame
# # Load Human real news
# with open('data/HR_prep.json', 'r') as file:
#     data = json.load(file)

# HR_prep_df = pd.DataFrame.from_dict(data, orient='index')
# HR_df = HR_prep_df['preprocessed_text']
# HR_df
# Out:
# 0       summer camp movie thatll make nostalgic childh...
# 1       info category richest business executive net w...
# 2       warning story contains major spoiler recent ep...
# 3       lil peep died overdose fentanyl generic xanax ...
# 4       goop kicking weekly podcast big way oprah big ...
#                               ...
# 8163    free real time breaking news alert sent straig...
# 8164    gilmore girl year life made netflix debut six ...
# 8165    airing according executive producer terry wron...
# 8166    thought season vanderpump rule couldnt get sca...
# 8167    cringeworthy video katie couric talking matt l...
# Name: preprocessed_text, Length: 8168, dtype: object

# %%
# Function to load JSON data into a DataFrame
def load_json_to_df(json_file):
    with open(json_file, 'r') as file:
        data = json.load(file)
    return pd.DataFrame.from_dict(data, orient='index')

# List of JSON files
json_files = ['HR_prep.json', 'HF_prep.json', 'MR_prep.json', 'MF_prep.json']
dfs = []

# Load each JSON file into a DataFrame and store them in a list
for json_file in json_files:
    df = load_json_to_df('data/' + json_file)
    dfs.append(df)

# Naming the DataFrames
HR_df, HF_df, MR_df, MF_df = dfs

# %%
HR = HR_df['preprocessed_text']
HR
# Out:
# 0       summer camp movie thatll make nostalgic childh...
# 1       info category richest business executive net w...
# 2       warning story contains major spoiler recent ep...
# 3       lil peep died overdose fentanyl generic xanax ...
# 4       goop kicking weekly podcast big way oprah big ...
#                               ...
# 8163    free real time breaking news alert sent straig...
# 8164    gilmore girl year life made netflix debut six ...
# 8165    airing according executive producer terry wron...
# 8166    thought season vanderpump rule couldnt get sca...
# 8167    cringeworthy video katie couric talking matt l...
# Name: preprocessed_text, Length: 8168, dtype: object

# %%
HF = HF_df['preprocessed_text']
HF
# Out:
# 0       close meghan markle prince harry announced eng...
# 1       kim kardashian kanye west pulling stop keep fa...
# 2       prince harry meghan currently live kensington ...
# 3       cant get enough biebs show back first week sea...
# 4       ben affleck keeping life three kid relationshi...
#                               ...
# 4079    shortage celebrity beef whether fight costars ...
# 4080    kim kardashian sister seem pretty unimpressed ...
# 4081    john got together found love cooking one earli...
# 4082    yikes le month giving birth baby stormi kylie ...
# 4083    beyonc knowles jay z welcomed twin according r...
# Name: preprocessed_text, Length: 4084, dtype: object

# %%
MR = MR_df['preprocessed_text']
MR
# Out:
# 0       summer around corner perfect time take trip me...
# 1       charrisse jackson jordan american reality tele...
# 2       warning story contains major spoiler recent ep...
# 3       pima county office medical examiner confirmed ...
# 4       goop kicking weekly podcast big way oprah winf...
#                               ...
# 4164    kailyn lowry star teen mom recently opened reg...
# 4165    farrah abraham star mtvs teen mom og decided d...
# 4166    real housewife new jersey star kim depaola rec...
# 4167    golden globe red carpet one unlike time initia...
# 4168    kanye west renowned rapper time grammy winner ...
# Name: preprocessed_text, Length: 4169, dtype: object

# %%
MF = MF_df['preprocessed_text']
MF
# Out:
# 0       excitement anticipation air royal family get r...
# 1       wake kim kardashians traumatic paris robbery r...
# 2       uke duchess sussex prince harry meghan markle ...
# 3       surprise turn event former president barack ob...
# 4       unexpected turn event hollywood actress jennif...
#                               ...
# 4079    bid farewell dramafilled year anticipation wha...
# 4080    reality television star kim kardashian facing ...
# 4081    chrissy teigen popular model social medium per...
# 4082    kylie jenner travis scott relationship may jeo...
# 4083    according exclusive report tmz beyonc jay z na...
# Name: preprocessed_text, Length: 4084, dtype: object
